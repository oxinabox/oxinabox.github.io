# %%
using Base.Test
using Plots

# %%
abstract type RolledResult end

struct Success <: RolledResult
end

struct Critical <: RolledResult
end

struct Fumble <: RolledResult
end

import Base: +
+(r::RolledResult, ::Success) = r
+( ::RolledResult, ::Critical) = Critical()
+( ::RolledResult, ::Fumble) = Fumble()
+( ::Fumble,       ::Critical) = Success()
+( ::Critical,     ::Fumble) = Success()
# Out:
# + (generic function with 201 methods)

# %%
@testset "result stacking" begin
    @test Critical()+Critical() == Critical()
    @test Fumble()+Critical() == Success()
    @test Fumble()+Success() == Fumble()
end
# Out:
# Test Summary:   | Pass  Total
# result stacking |    3      3
# Base.Test.DefaultTestSet("result stacking", Any[], 3, false)

# %%
"""
    rolltable(crit_range=1, fumble_range=1, nsides=6)

Returns a table of `RolledResult`s, based on the parameters given.
"""
function rolltable(crit_range=1, fumble_range=1, nsides=6)
    possible_results = Vector{RolledResult}(nsides)
    possible_results[:] .= Success()
    # I have defined addition on RolledResults for this:
    possible_results[1:fumble_range] .+= Fumble()
    possible_results[end-crit_range+1:end] .+= Critical()
    possible_results
end
# Out:
# rolltable

# %%
@testset "rolltable" begin
    @test rolltable()[1]==Fumble()
    @test rolltable()[end]==Critical()
    @test all(rolltable()[2:end-1].== Success())
    
    @test rolltable(2,2)== [Fumble(),Fumble(), Success(),Success(),Critical(), Critical()]
    
    #If crit range and fumble range overlap then they cancel out.
    @test rolltable(6,1)== [Success(),Critical(),Critical(),Critical(),Critical(), Critical()]
    @test rolltable(6,2)== [Success(),Success(),Critical(),Critical(),Critical(), Critical()]
end
# Out:
# Test Summary: | Pass  Total
# rolltable     |    6      6
# Base.Test.DefaultTestSet("rolltable", Any[], 6, false)

# %%
abstract type Mechanic end
struct Default <: Mechanic
end

# %%
function roll_skill_check(::Default, crit_range=1, fumble_range=1, nsides=6)
    result = rand(rolltable(crit_range, fumble_range, nsides))
    final_result(::Success) = 0
    final_result(::Fumble)  = -1
    final_result(::Critical) = +1
    final_result(result)
end
# Out:
# roll_skill_check (generic function with 8 methods)

# %%
roll_skill_check(Default(), 1,1)
# Out:
# 0

# %%
function display_simulation(res)
    @show mean(res)
    @show std(res)
    @show minimum(res)
    @show quantile(res,0.25)
    @show median(res)
    @show quantile(res,0.75)
    @show maximum(res)
    histogram(res; xlims=(-3,3),bar_width=1, ylims=(0,length(res)))
end
# Out:
# display_simulation (generic function with 1 method)

# %%
display_simulation([roll_skill_check(Default(), 1,1) for _ in 1:10_000])
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5800)" points="
# 48.6962,375.813 580.315,375.813 580.315,11.811 48.6962,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="11" width="533" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.353 48.6962,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.353 137.299,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.353 225.902,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.353 314.506,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.353 403.109,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.353 491.712,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,303.013 572.341,303.013
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,230.212 572.341,230.212
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,157.412 572.341,157.412
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,84.6115 572.341,84.6115
#   "/>
# <polyline clip-path="url(#clip5802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,11.811 572.341,11.811
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,11.811
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,303.013 56.6705,303.013
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,230.212 56.6705,230.212
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,157.412 56.6705,157.412
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,84.6115 56.6705,84.6115
#   "/>
# <polyline clip-path="url(#clip5800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,11.811 56.6705,11.811
#   "/>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 307.513)" x="42.6962" y="307.513">2000</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 234.712)" x="42.6962" y="234.712">4000</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 161.912)" x="42.6962" y="161.912">6000</text>
# </g>
# <g clip-path="url(#clip5800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 89.1115)" x="42.6962" y
# mean(res) = -0.002
# std(res) = 0.5739590080260866
# minimum(res) = -1
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 0.0
# maximum(res) = 1

# %% [markdown]
# ## Now lets consider a different mechanic
#
# Rather than a crit(/fumble) directly increasing(/decreasing) your result,
# what if your rolled again such that a success would be an increase to yourresult.
# and a crit(/fumble) would be another reroll.
# Thus giving you the change to  double crit (/double fumble)

# %%
struct Explosions <: Mechanic
end

function roll_skill_check(::Explosions, crit_range=1, fumble_range=1, nsides=6)
    result = rand(rolltable(crit_range, fumble_range, nsides))
    final_result(::Success) = 0
    final_result(::Fumble)  = -1 + roll_skill_check(Explosions(), crit_range, fumble_range, nsides)
    final_result(::Critical) = 1 + roll_skill_check(Explosions(), crit_range, fumble_range, nsides)
    final_result(result)
end
# Out:
# roll_skill_check (generic function with 8 methods)

# %%
display_simulation([roll_skill_check(Explosions(), 1,1) for _ in 1:10_000])
# Out:
# mean(res) = 0.0123
# std(res) = 0.7056900947660988
# minimum(res) = -6
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 0.0
# maximum(res) = 5
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip7800)" points="
# 48.6962,375.813 580.315,375.813 580.315,11.811 48.6962,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="11" width="533" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.353 48.6962,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.353 137.299,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.353 225.902,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.353 314.506,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.353 403.109,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.353 491.712,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.353 580.315,17.2711
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,303.013 572.341,303.013
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,230.212 572.341,230.212
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,157.412 572.341,157.412
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,84.6115 572.341,84.6115
#   "/>
# <polyline clip-path="url(#clip7802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,11.811 572.341,11.811
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,11.811
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.353
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,303.013 56.6705,303.013
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,230.212 56.6705,230.212
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,157.412 56.6705,157.412
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,84.6115 56.6705,84.6115
#   "/>
# <polyline clip-path="url(#clip7800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,11.811 56.6705,11.811
#   "/>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 307.513)" x="42.6962" y="307.513">2000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 234.712)" x="42.6962" y="234.712">4000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 161.912)" x="42.6962" y="161.912">6000</text>
# </g>
# <g clip-path="url(#clip7800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 89.1115)" x="42.6962" y

# %%
function display_contrast(crit_range, fumble_range, nsims=10_000)
    plt = display_simulation([roll_skill_check(Default(), crit_range, fumble_range) for _ in 1:nsims])
    title!(plt, "Default $(crit_range):$(fumble_range)")
    IJulia.display(plt)
    println("---------------- vs Explosions -------------")
    plt=display_simulation([roll_skill_check(Explosions(), crit_range, fumble_range) for _ in 1:nsims])
    title!(plt, "Explosions $(crit_range):$(fumble_range)")
    IJulia.display(plot!(plt))
end

display_contrast(1,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0600)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip0602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip0600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip0600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0800)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip0802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip0800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip0800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.0041
# std(res) = 0.5705398685229257
# minimum(res) = -1
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 0.0
# maximum(res) = 1
# ---------------- vs Explosions -------------
# mean(res) = 0.0057
# std(res) = 0.7020803384799836
# minimum(res) = -5
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 0.0
# maximum(res) = 5

# %%
display_contrast(2,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1000)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip1002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip1000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip1000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.1593
# std(res) = 0.6849601645663078
# minimum(res) = -1
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 1
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# ---------------- vs Explosions -------------
# mean(res) = 0.3247
# std(res) = 1.0355564435195077
# minimum(res) = -5
# quantile(res, 0.25) = 0.0
# median(res) = 0.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 8

# %%
display_contrast(3,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.3449
# std(res) = 0.7382401302076342
# minimum(res) = -1
# quantile(res, 0.25) = 0.0
# median(res) = 1.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 1
# ---------------- vs Explosions -------------
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1600)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip1602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip1600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip1600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 1.0173
# std(res) = 1.753655679095552
# minimum(res) = -5
# quantile(res, 0.25) = 0.0
# median(res) = 1.0
# quantile(res, 0.75) = 2.0
# maximum(res) = 15

# %%
display_contrast(4,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1800)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip1802)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip1800)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip1800)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.4978
# std(res) = 0.7610867790919316
# minimum(res) = -1
# quantile(res, 0.25) = 0.0
# median(res) = 1.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 1
# ---------------- vs Explosions -------------
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2000)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2000)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip2002)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip2000)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip2000)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 2.9526
# std(res) = 3.6762079226383597
# minimum(res) = -5
# quantile(res, 0.25) = 0.0
# median(res) = 2.0
# quantile(res, 0.75) = 4.0
# maximum(res) = 36

# %%
display_contrast(5,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2200)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip2202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip2200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip2200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.6636
# std(res) = 0.748124995639706
# minimum(res) = -1
# quantile(res, 0.25) = 1.0
# median(res) = 1.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 1
# ---------------- vs Explosions -------------
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.

# %%
rolltable(5, 1) #This is not going to workout, infinite rolls
# Out:
# 6-element Array{RolledResult,1}:
#  Fumble()
#  Critical()
#  Critical()
#  Critical()
#  Critical()
#  Critical()

# %%
display_contrast(6,1)
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip00">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip01">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2600)" points="
# 48.6962,375.813 580.315,375.813 580.315,31.4961 48.6962,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip02">
#     <rect x="48" y="31" width="533" height="345"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   48.6962,370.649 48.6962,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   137.299,370.649 137.299,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   225.902,370.649 225.902,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   314.506,370.649 314.506,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   403.109,370.649 403.109,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   491.712,370.649 491.712,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,370.649 580.315,36.6608
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,375.813 572.341,375.813
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,306.95 572.341,306.95
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,238.086 572.341,238.086
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,169.223 572.341,169.223
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,100.36 572.341,100.36
#   "/>
# <polyline clip-path="url(#clip2602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.6705,31.4961 572.341,31.4961
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 580.315,375.813
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,31.4961
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 48.6962,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   137.299,375.813 137.299,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   225.902,375.813 225.902,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   314.506,375.813 314.506,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   403.109,375.813 403.109,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   491.712,375.813 491.712,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,375.813 580.315,370.649
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,375.813 56.6705,375.813
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,306.95 56.6705,306.95
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,238.086 56.6705,238.086
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,169.223 56.6705,169.223
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,100.36 56.6705,100.36
#   "/>
# <polyline clip-path="url(#clip2600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   48.6962,31.4961 56.6705,31.4961
#   "/>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 48.6962, 389.613)" x="48.6962" y="389.613">-3</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 137.299, 389.613)" x="137.299" y="389.613">-2</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 225.902, 389.613)" x="225.902" y="389.613">-1</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 314.506, 389.613)" x="314.506" y="389.613">0</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 403.109, 389.613)" x="403.109" y="389.613">1</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 491.712, 389.613)" x="491.712" y="389.613">2</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 580.315, 389.613)" x="580.315" y="389.613">3</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 380.313)" x="42.6962" y="380.313">0</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 311.45)" x="42.6962" y="311.45">2000</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 242.586)" x="42.6962" y="242.586">4000</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 173.723)" x="42.6962" y="173.723">6000</text>
# </g>
# <g clip-path="url(#clip2600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 42.6962, 104.86)" x="42.6962" y="10
# mean(res) = 0.8335
# std(res) = 0.3725474857825727
# minimum(res) = 0
# quantile(res, 0.25) = 1.0
# median(res) = 1.0
# quantile(res, 0.75) = 1.0
# maximum(res) = 1
# ---------------- vs Explosions -------------
# mean(res) = 4.9318
# std(res) = 5.408315241124054
# minimum(res) = 0
# quantile(res, 0.25) = 1.0
# median(res) = 3.0
# quantile(res, 0.75) = 7.0
# maximum(res) = 42
